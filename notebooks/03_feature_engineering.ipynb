# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/sales-forecasting-ml-project/blob/main/notebooks/03_feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 3: Feature Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/monthly-car-sales.csv", parse_dates=["Month"])

df.set_index("Month", inplace=True)

df.head()
# Out:
#             Sales
# Month
# 1960-01-01   6550
# 1960-02-01   8728
# 1960-03-01  12026
# 1960-04-01  14395
# 1960-05-01  14587

# %%
df["year"] = df.index.year
df["month"] = df.index.month

# %%
df["lag_1"] = df["Sales"].shift(1)
df["lag_12"] = df["Sales"].shift(12)

# %%
df.dropna(inplace=True)

# %%
df.to_csv("/content/sales_features.csv")
